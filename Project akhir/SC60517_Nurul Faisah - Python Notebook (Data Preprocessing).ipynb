# %% [markdown]
# ### **Team 5A - Sevengers (Kompi 5)**

# %% [markdown]
# ##### **Anggota Tim 5A**
# > ##### 1. Intan Puspita Sari (SC60522)
# > ##### 2. Tyasa Obieta Yuliadri Yanti Putri (SC60525)
# > ##### 3. Nabilah Dita Ramadhana (SC60523)
# > ##### 4. Akmal Dwiki Wijaya (SC60512)
# > ##### 5. Nurul Faisah (SC60517)
# > ##### 6. Naaifah Putri Ramadhani (SC60508)
# > ##### 7. Mohammad Rizky Ramadhan (SC60507)
#
# ##### **Mentor : Ka Azis Muslim**
#
# ##### **Facil : Ka Renita Yulistiana**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns

# %% [markdown]
# ### **Melihat Data per File CSV**

# %% [markdown]
# #### **Lowongan Kerja**

# %%
df_lowongan = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/lowongan_kerja.csv')
df_lowongan
# Out:
#        id_pekerjaan  id_perusahaan  \
# 0        3757940104       553718.0
# 1        3757940025      2192142.0
# 2        3757938019       474443.0
# 3        3757938018     18213359.0
# 4        3757937095       437225.0
# ...             ...            ...
# 33241     133114754     77766802.0
# 33242     108965123            NaN
# 33243     102339515     52132271.0
# 33244      85008768            NaN
# 33245       3958427       630152.0
#
#                                                    judul  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# ...

# %% [markdown]
# #### **Upah**

# %%
df_upah = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/upah.csv')
df_upah
# Out:
#        id_gaji  id_pekerjaan  gaji_maksimal  gaji_median  gaji_minimal  \
# 0            1    3378133231           30.0          NaN          22.0
# 1            2    3690843087        65000.0          NaN       55000.0
# 2            3    3691794313           22.0          NaN          19.0
# 3            4    3691795389        70000.0          NaN       68000.0
# 4            5    3691797089           22.0          NaN          18.0
# ...        ...           ...            ...          ...           ...
# 13347    13736    3756116147       210000.0          NaN      170000.0
# 13348    13737    3757723474       130000.0          NaN      110000.0
# 13349    13738    3757485745            NaN         48.0           NaN
# 13350    13739    3757490898        60000.0          NaN       45000.0
# 13351    13740    3757486249       115000.0          NaN      100000.0
#
#       periode_pembayaran mata_uang jenis_kompensasi
# 0                 HOURLY       USD      BASE_SALARY
# ...

# %% [markdown]
# #### **Spesialisasi Perusahaan**

# %%
df_spesialisasi_perusahaan  = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/spesialisasi_perusahaan.csv')
df_spesialisasi_perusahaan
# Out:
#        id_perusahaan                                       spesialisasi
# 0           81149246                          Childrens Music Education
# 1           81149246                          Foundational Music Theory
# 2           81149246                                Child Music Lessons
# 3           81149246                          social emotional learning
# 4           81149246                       social emotional development
# ...              ...                                                ...
# 78400        2293632                                     LED Billboards
# 78401        2293632                         Electronic Message Centers
# 78402        2293632                                    Digital Signage
# 78403        2293632                            Outdoor Digital Signage
# 78404         373873  System Integrator for ERPs and n-tier web base...
#
# [78405 rows x 2 columns]

# %% [markdown]
# #### **Skill Pekerjaan**

# %%
df_skill_pekerjaan = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/skill_pekerjaan.csv')
df_skill_pekerjaan
# Out:
#        id_pekerjaan singkatan_kemampuan
# 0        3690843087                ACCT
# 1        3690843087                 FIN
# 2        3691763971                MGMT
# 3        3691763971                MNFC
# 4        3691775263                MGMT
# ...             ...                 ...
# 56586    3757780487                HCPR
# 56587    3757934256                DSGN
# 56588    3757934256                 ART
# 56589    3757934256                  IT
# 56590    3757498232                 ADM
#
# [56591 rows x 2 columns]

# %% [markdown]
# #### **Perusahaan**

# %%
df_perusahaan = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/perusahaan.csv')
df_perusahaan
# Out:
#        id_perusahaan                                    nama  \
# 0               1009                                     IBM
# 1               1016                           GE HealthCare
# 2               1021                                GE Power
# 3               1025              Hewlett Packard Enterprise
# 4               1028                                  Oracle
# ...              ...                                     ...
# 11356     3700144594                                  BYREDO
# 11357     3700144710  Pros2Plan, a division of Spinnaker SCA
# 11358     3700147810                       Ascendo Resources
# 11359     3700150295                          The Crox Group
# 11360     3700152513                       Sidley Austin LLP
#
#                                                deskripsi  ukuran_perusahaan  \
# 0      At IBM, we do more than work. We create. We cr...                7.0
# 1      Every day millions of people feel the impact o...                7.0
# ...

# %% [markdown]
# #### **Kemampuan**

# %%
df_kemampuan = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/kemampuan.csv')
df_kemampuan
# Out:
#    singkatan_kemampuan          nama_kemampuan
# 0                 PRCH              Purchasing
# 1                 SUPL            Supply Chain
# 2                   PR        Public Relations
# 3                  SCI                 Science
# 4                 STRA       Strategy/Planning
# 5                  WRT         Writing/Editing
# 6                   QA       Quality Assurance
# 7                 DIST            Distribution
# 8                 PROD              Production
# 9                 PRJM      Project Management
# 10                ADVR             Advertising
# 11                RSCH                Research
# 12                  HR         Human Resources
# 13                 LGL                   Legal
# 14                PRDM      Product Management
# 15                MRKT               Marketing
# 16                 EDU               Education
# 17                TRNG                Training
# 18                ANLS                 Analyst
# ...

# %% [markdown]
# #### **Jumlah Karyawan**

# %%
df_jumlah_karyawan = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/jumlah_karyawan.csv')
df_jumlah_karyawan
# Out:
#        id_perusahaan  jumlah_karyawan  jumlah_follower  waktu_dicatat
# 0           81149246                6               91   1.692645e+09
# 1           10033339                3              187   1.692645e+09
# 2            6049228               20               82   1.692645e+09
# 3            2641066               45             2336   1.692645e+09
# 4           96649998                0                2   1.692645e+09
# ...              ...              ...              ...            ...
# 14270         829374             2455            58753   1.699140e+09
# 14271           5574             8281            96163   1.699140e+09
# 14272       10135152             6322            31953   1.699140e+09
# 14273         373873               45            30298   1.699140e+09
# 14274           7428             6901            76462   1.699140e+09
#
# [14275 rows x 4 columns]

# %% [markdown]
# #### **Industri**

# %%
df_industri = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/industri.csv')
df_industri
# Out:
#      id_industri                             nama_industri
# 0              1           Defense and Space Manufacturing
# 1              3           Computer Hardware Manufacturing
# 2              4                      Software Development
# 3              5              Computer Networking Products
# 4              6      Technology, Information and Internet
# ..           ...                                       ...
# 224         3240         Renewable Energy Power Generation
# 225         3241  Renewable Energy Equipment Manufacturing
# 226         3242                      Engineering Services
# 227         3243             Services for Renewable Energy
# 228         3251  Climate Technology Product Manufacturing
#
# [229 rows x 2 columns]

# %% [markdown]
# #### **Industri Pekerjaan**

# %%
df_industri_pekerjaan = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/industri_pekerjaan.csv')
df_industri_pekerjaan
# Out:
#        id_pekerjaan  id_industri
# 0        3378133231           68
# 1        3497509795           96
# 2        3690843087           47
# 3        3691775263          112
# 4        3691779379           80
# ...             ...          ...
# 44086    3757486249           47
# 44087    3757486249           43
# 44088    3757780487          104
# 44089    3757934256           80
# 44090    3757498232           14
#
# [44091 rows x 2 columns]

# %% [markdown]
# #### **Industri Perusahaan**

# %%
df_industri_perusahaan = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/industri_perusahaan.csv')
df_industri_perusahaan
# Out:
#        id_perusahaan                               industri
# 0           81149246                       Higher Education
# 1           10033339      Information Technology & Services
# 2            6049228                             Accounting
# 3            2641066  Electrical & Electronic Manufacturing
# 4           96649998                Marketing & Advertising
# ...              ...                                    ...
# 12596       10143362                            Hospitality
# 12597        2293632                   Software Development
# 12598       18754113                Staffing and Recruiting
# 12599       10135152              Government Administration
# 12600         373873          IT Services and IT Consulting
#
# [12601 rows x 2 columns]

# %% [markdown]
# #### **Benefit**

# %%
df_benefit = pd.read_csv ('/content/drive/MyDrive/Tim 5A Final Project Drive/benefit.csv')
df_benefit
# Out:
#        id_pekerjaan  benefit                 jenis
# 0        3690843087        0     Medical insurance
# 1        3690843087        0      Dental insurance
# 2        3690843087        0                401(k)
# 3        3690843087        0  Paid maternity leave
# 4        3690843087        0  Disability insurance
# ...             ...      ...                   ...
# 29320    3757934256        0                401(k)
# 29321    3757934256        0  Paid paternity leave
# 29322    3757934256        0  Paid maternity leave
# 29323    3757934256        0  Disability insurance
# 29324    3757498232        1     Medical insurance
#
# [29325 rows x 3 columns]

# %% [markdown]
# ### **Data Prepocessing**

# %% [markdown]
# #### **Merge Data Lowongan Kerja dan Data Upah**

# %%
# Drop kolom yang tidak berpengaruh pada data lowongan kerja.

columns_to_drop=[
    'gaji_maksimal',
    'gaji_tengah',
    'gaji_minimal',
    'periode_pembayaran',
    'mata_uang',
    'tipe_kompensasi',
    'domain_penyelenggaraan',
    'disponsori',
    'tampilan',
    'url_posting_pekerjaan',
    'url_pendaftaran',
    'tipe_pendaftaran',
    'waktu_kedaluwarsa',
    'waktu_daftar',
    'lamaran']

df_lowongan = df_lowongan.drop(columns=columns_to_drop)

# %%
# Menggabungkan data Upah dengan data Lowongan Kerja.

df_combined = pd.merge(df_lowongan, df_upah, on='id_pekerjaan', how='left')

# %%
df_combined.head()
# Out:
#    id_pekerjaan  id_perusahaan  \
# 0    3757940104       553718.0
# 1    3757940025      2192142.0
# 2    3757938019       474443.0
# 3    3757938018     18213359.0
# 4    3757937095       437225.0
#
#                                                judul  \
# 0                              Hearing Care Provider
# 1  Shipping & Receiving Associate 2nd shift (Beav...
# 2                               Manager, Engineering
# 3                                               Cook
# 4        Principal Cloud Security Architect (Remote)
#
#                                            deskripsi  \
# 0  Overview\n\nHearingLife is a national hearing ...
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...
# 2  \nThe TSUBAKI name is synonymous with excellen...
# 3  descriptionTitle\n\n Looking for a great oppor...
# 4  Job Summary\nAt iHerb, we are on a mission to ...
#
#   jenis_pekerjaan_terformat            lokasi  diperbolehkan_jarak_jauh  \
# ...

# %%
nan_per_column = df_lowongan.isna().sum()
nan_per_column
# Out:
# id_pekerjaan                        0
# id_perusahaan                     654
# judul                               0
# deskripsi                           1
# jenis_pekerjaan_terformat           0
# lokasi                              0
# diperbolehkan_jarak_jauh        28444
# tingkat_pengalaman_terformat     9181
# deskripsi_keterampilan          32909
# jenis_pekerjaan                     0
# dtype: int64

# %%
nan_per_column = df_upah.isna().sum()
nan_per_column
# Out:
# id_gaji                   0
# id_pekerjaan              0
# gaji_maksimal          2241
# gaji_median           11111
# gaji_minimal           2241
# periode_pembayaran        0
# mata_uang                 0
# jenis_kompensasi          0
# dtype: int64

# %%
nan_per_column = df_combined.isna().sum()
nan_per_column
# Out:
# id_pekerjaan                        0
# id_perusahaan                     654
# judul                               0
# deskripsi                           1
# jenis_pekerjaan_terformat           0
# lokasi                              0
# diperbolehkan_jarak_jauh        28444
# tingkat_pengalaman_terformat     9181
# deskripsi_keterampilan          32909
# jenis_pekerjaan                     0
# id_gaji                         19894
# gaji_maksimal                   22135
# gaji_median                     31005
# gaji_minimal                    22135
# periode_pembayaran              19894
# mata_uang                       19894
# jenis_kompensasi                19894
# dtype: int64

# %%
# Drop kolom id_gaji.

df_combined = df_combined.drop(columns = ['id_gaji'])

# %% [markdown]
# #### **Merge DataFrame Skill Pekerjaan dengan Dataframe Sebelumnya**

# %%
# Combine all the skills of the same job id.

df_skill_pekerjaan = df_skill_pekerjaan.groupby('id_pekerjaan')['singkatan_kemampuan'].agg(lambda kemampuan: ', '.join(kemampuan)).reset_index()
df_skill_pekerjaan
# Out:
#        id_pekerjaan singkatan_kemampuan
# 0           3958427       DSGN, ART, IT
# 1          85008768            SALE, BD
# 2         102339515            BD, SALE
# 3         108965123                 ADM
# 4         133114754            SALE, BD
# ...             ...                 ...
# 32417    3757937095                  IT
# 32418    3757938018          MGMT, MNFC
# 32419    3757938019                 ENG
# 32420    3757940025          MGMT, MNFC
# 32421    3757940104                OTHR
#
# [32422 rows x 2 columns]

# %%
# Merge job skills as all skills combine above.

df_combined = pd.merge(df_combined, df_skill_pekerjaan, on="id_pekerjaan", how="left")
df_combined
# Out:
#        id_pekerjaan  id_perusahaan  \
# 0        3757940104       553718.0
# 1        3757940025      2192142.0
# 2        3757938019       474443.0
# 3        3757938018     18213359.0
# 4        3757937095       437225.0
# ...             ...            ...
# 33241     133114754     77766802.0
# 33242     108965123            NaN
# 33243     102339515     52132271.0
# 33244      85008768            NaN
# 33245       3958427       630152.0
#
#                                                    judul  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# ...

# %% [markdown]
# #### **Gabungkan Data Benefit dengan DataFrame Sebelumnya**

# %%
# Drop kolom 'benefit' karena tidak berpengaruh dengn varibel target.
df_benefit = df_benefit.drop('benefit', axis=1)

# Combine all the benifits of the same job id.
df_benefit = df_benefit.groupby('id_pekerjaan')['jenis'].agg(lambda benefit: ', '.join(benefit)).reset_index()
df_benefit
# Out:
#        id_pekerjaan                                              jenis
# 0           3958427                                  Medical insurance
# 1          85008768  Medical insurance, Vision insurance, Dental in...
# 2         133114754        Medical insurance, 401(k), Vision insurance
# 3         529257371  Medical insurance, Vision insurance, Dental in...
# 4         967848246                                             401(k)
# ...             ...                                                ...
# 11642    3757935025     401(k), Vision insurance, Disability insurance
# 11643    3757935381                           401(k), Vision insurance
# 11644    3757935384                                             401(k)
# 11645    3757937004     Vision insurance, 401(k), Disability insurance
# 11646    3757940104            Medical insurance, Disability insurance
#
# [11647 rows x 2 columns]

# %%
# Gabungkan Dataframe sebelumnya dengan data benefit.

df_combined = pd.merge(df_combined, df_benefit, on="id_pekerjaan", how="left")

# %% [markdown]
# #### **Menggabungkan Data Perusahaan**

# %%
# Drop beberapa kolom yang kurang berpengaruh.

columns_to_drop=['kode_pos', 'alamat', 'url']
df_perusahaan = df_perusahaan.drop(columns=columns_to_drop)
df_perusahaan.head()
# Out:
#    id_perusahaan                        nama  \
# 0           1009                         IBM
# 1           1016               GE HealthCare
# 2           1021                    GE Power
# 3           1025  Hewlett Packard Enterprise
# 4           1028                      Oracle
#
#                                            deskripsi  ukuran_perusahaan  \
# 0  At IBM, we do more than work. We create. We cr...                7.0
# 1  Every day millions of people feel the impact o...                7.0
# 2  GE Power, part of GE Vernova, is a world energ...                7.0
# 3  Official LinkedIn of Hewlett Packard Enterpris...                7.0
# 4  We’re a cloud technology company that provides...                7.0
#
#   negara_bagian negara              kota
# 0            NY     US  Armonk, New York
# 1             0     US           Chicago
# 2            NY     US       Schenectady
# 3         Texas     US           Houston
# 4         Texas     US            Austin

# %%
df_perusahaan.rename(columns={'nama': 'nama_perusahaan',
                             'deskripsi': 'deskripsi_perusahaan',
                             'negara_bagian': 'negara_bagian_perusahaan',
                             'negara': 'negara_perusahaan',
                             'kota': 'kota_perusahaan'},
                    inplace=True)

# %%
df_combined = pd.merge(df_combined, df_perusahaan, on='id_perusahaan', how='left')

# %%
df_combined.rename(columns={'judul': 'nama_pekerjaan',
                             'deskripsi': 'deskripsi_pekerjaan',
                             'lokasi': 'lokasi_pekerjaan',
                             'tipe': 'benefit_pekerjaan',
                             'singkatan_kemampuan': 'kode_kemampuan'},
                    inplace=True)

# %%
dfs = df_combined

# %%
dfs.head()
# Out:
#    id_pekerjaan  id_perusahaan  \
# 0    3757940104       553718.0
# 1    3757940025      2192142.0
# 2    3757938019       474443.0
# 3    3757938018     18213359.0
# 4    3757937095       437225.0
#
#                                       nama_pekerjaan  \
# 0                              Hearing Care Provider
# 1  Shipping & Receiving Associate 2nd shift (Beav...
# 2                               Manager, Engineering
# 3                                               Cook
# 4        Principal Cloud Security Architect (Remote)
#
#                                  deskripsi_pekerjaan  \
# 0  Overview\n\nHearingLife is a national hearing ...
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...
# 2  \nThe TSUBAKI name is synonymous with excellen...
# 3  descriptionTitle\n\n Looking for a great oppor...
# 4  Job Summary\nAt iHerb, we are on a mission to ...
#
#   jenis_pekerjaan_terformat  lokasi_pekerjaan  diperbolehkan_jarak_jauh  \
# ...

# %%
dfs.columns
# Out:
# Index(['id_pekerjaan', 'id_perusahaan', 'nama_pekerjaan',
#        'deskripsi_pekerjaan', 'jenis_pekerjaan_terformat', 'lokasi_pekerjaan',
#        'diperbolehkan_jarak_jauh', 'tingkat_pengalaman_terformat',
#        'deskripsi_keterampilan', 'jenis_pekerjaan', 'gaji_maksimal',
#        'gaji_median', 'gaji_minimal', 'periode_pembayaran', 'mata_uang',
#        'jenis_kompensasi', 'kode_kemampuan', 'jenis', 'nama_perusahaan',
#        'deskripsi_perusahaan', 'ukuran_perusahaan', 'negara_bagian_perusahaan',
#        'negara_perusahaan', 'kota_perusahaan'],
#       dtype='object')

# %% [markdown]
# #### **Missing Value**

# %%
nan_per_column = df_combined.isna().sum()
nan_per_column
# Out:
# id_pekerjaan                        0
# id_perusahaan                     654
# nama_pekerjaan                      0
# deskripsi_pekerjaan                 1
# jenis_pekerjaan_terformat           0
# lokasi_pekerjaan                    0
# diperbolehkan_jarak_jauh        28444
# tingkat_pengalaman_terformat     9181
# deskripsi_keterampilan          32909
# jenis_pekerjaan                     0
# gaji_maksimal                   22135
# gaji_median                     31005
# gaji_minimal                    22135
# periode_pembayaran              19894
# mata_uang                       19894
# jenis_kompensasi                19894
# kode_kemampuan                   1212
# jenis                           21599
# nama_perusahaan                   705
# deskripsi_perusahaan              890
# ukuran_perusahaan                2150
# negara_bagian_perusahaan          712
# negara_perusahaan                 701
# kota_perusahaan                   702
# dtype: int64

# %%
dfs['gaji_maksimal']= dfs['gaji_maksimal'].fillna(value=0)
dfs
# Out:
#        id_pekerjaan  id_perusahaan  \
# 0        3757940104       553718.0
# 1        3757940025      2192142.0
# 2        3757938019       474443.0
# 3        3757938018     18213359.0
# 4        3757937095       437225.0
# ...             ...            ...
# 33241     133114754     77766802.0
# 33242     108965123            NaN
# 33243     102339515     52132271.0
# 33244      85008768            NaN
# 33245       3958427       630152.0
#
#                                           nama_pekerjaan  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# ...

# %%
dfs['gaji_median']= dfs['gaji_median'].fillna(value=0)
dfs
# Out:
#        id_pekerjaan  id_perusahaan  \
# 0        3757940104       553718.0
# 1        3757940025      2192142.0
# 2        3757938019       474443.0
# 3        3757938018     18213359.0
# 4        3757937095       437225.0
# ...             ...            ...
# 33241     133114754     77766802.0
# 33242     108965123            NaN
# 33243     102339515     52132271.0
# 33244      85008768            NaN
# 33245       3958427       630152.0
#
#                                           nama_pekerjaan  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# ...

# %%
dfs['gaji_minimal']= dfs['gaji_minimal'].fillna(value=0)
dfs
# Out:
#        id_pekerjaan  id_perusahaan  \
# 0        3757940104       553718.0
# 1        3757940025      2192142.0
# 2        3757938019       474443.0
# 3        3757938018     18213359.0
# 4        3757937095       437225.0
# ...             ...            ...
# 33241     133114754     77766802.0
# 33242     108965123            NaN
# 33243     102339515     52132271.0
# 33244      85008768            NaN
# 33245       3958427       630152.0
#
#                                           nama_pekerjaan  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# ...

# %% [markdown]
# > Berdasarkan pertimbangan dan masukan dari kaka Mentor, dikarenakan Tim Sevengers akan melakukan prediksi gaji, makan sebaiknya missing value yang terdapat dalam fitur `gaji_maksimal`, `gaji_median`, `gaji_minimal` diisi dengan nilai "0". Sehingga dalam prediksi gaji hadapan, dapat diketahui berapa jumlah gaji pasti sesuai dengan karakteristik tertentu.

# %%
# Frekuensi Nilai Unik.

value_counts = dfs['periode_pembayaran'].value_counts()
print(value_counts)
# Out:
# periode_pembayaran
# YEARLY     8009
# HOURLY     5036
# MONTHLY     224
# WEEKLY       82
# ONCE          1
# Name: count, dtype: int64

# %%
# Mengubah Periode Pembayaran menjadi MONTHLY.

def convert_to_monthly_count(row):
    periode_pembayaran = row['periode_pembayaran']
    gaji_minimal = row['gaji_minimal']

    if periode_pembayaran == 'YEARLY':
        return gaji_minimal / 12
    elif periode_pembayaran == 'MONTHLY':
        return gaji_minimal
    elif periode_pembayaran == 'WEEKLY':
        return gaji_minimal * 4
    elif periode_pembayaran == 'HOURLY':
        # Misalkan 40 jam per minggu,
        return gaji_minimal * 40 * 4
    elif periode_pembayaran == 'ONCE':
        return gaji_minimal
    else:
        return gaji_minimal

dfs['gaji_bulanan_minimal'] = dfs.apply(convert_to_monthly_count, axis=1)

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_pekerjaan                  33246 non-null  int64
#  1   id_perusahaan                 32592 non-null  float64
#  2   nama_pekerjaan                33246 non-null  object
#  3   deskripsi_pekerjaan           33245 non-null  object
#  4   jenis_pekerjaan_terformat     33246 non-null  object
#  5   lokasi_pekerjaan              33246 non-null  object
#  6   diperbolehkan_jarak_jauh      4802 non-null   float64
#  7   tingkat_pengalaman_terformat  24065 non-null  object
#  8   deskripsi_keterampilan        337 non-null    object
#  9   jenis_pekerjaan               33246 non-null  object
#  10  gaji_maksimal                 33246 non-null  float64
#  11  gaji_median                   33246 non-null  float64
# ...

# %%
dfs.head()
# Out:
#    id_pekerjaan  id_perusahaan  \
# 0    3757940104       553718.0
# 1    3757940025      2192142.0
# 2    3757938019       474443.0
# 3    3757938018     18213359.0
# 4    3757937095       437225.0
#
#                                       nama_pekerjaan  \
# 0                              Hearing Care Provider
# 1  Shipping & Receiving Associate 2nd shift (Beav...
# 2                               Manager, Engineering
# 3                                               Cook
# 4        Principal Cloud Security Architect (Remote)
#
#                                  deskripsi_pekerjaan  \
# 0  Overview\n\nHearingLife is a national hearing ...
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...
# 2  \nThe TSUBAKI name is synonymous with excellen...
# 3  descriptionTitle\n\n Looking for a great oppor...
# 4  Job Summary\nAt iHerb, we are on a mission to ...
#
#   jenis_pekerjaan_terformat  lokasi_pekerjaan  diperbolehkan_jarak_jauh  \
# ...

# %%
dfs.isna().sum()
# Out:
# id_pekerjaan                        0
# id_perusahaan                     654
# nama_pekerjaan                      0
# deskripsi_pekerjaan                 1
# jenis_pekerjaan_terformat           0
# lokasi_pekerjaan                    0
# diperbolehkan_jarak_jauh        28444
# tingkat_pengalaman_terformat     9181
# deskripsi_keterampilan          32909
# jenis_pekerjaan                     0
# gaji_maksimal                       0
# gaji_median                         0
# gaji_minimal                        0
# periode_pembayaran              19894
# mata_uang                       19894
# jenis_kompensasi                19894
# kode_kemampuan                   1212
# jenis                           21599
# nama_perusahaan                   705
# deskripsi_perusahaan              890
# ukuran_perusahaan                2150
# negara_bagian_perusahaan          712
# negara_perusahaan                 701
# kota_perusahaan                   702
# gaji_bulanan_minimal                0
# ...

# %%
df_combined['ukuran_perusahaan'].fillna(value='0.0', inplace=True)
df_combined['id_perusahaan'].fillna(value='0.0', inplace=True)
df_combined['diperbolehkan_jarak_jauh'].fillna(value='0.0', inplace=True)
df_combined
# Out:
#        id_pekerjaan id_perusahaan  \
# 0        3757940104      553718.0
# 1        3757940025     2192142.0
# 2        3757938019      474443.0
# 3        3757938018    18213359.0
# 4        3757937095      437225.0
# ...             ...           ...
# 33241     133114754    77766802.0
# 33242     108965123           0.0
# 33243     102339515    52132271.0
# 33244      85008768           0.0
# 33245       3958427      630152.0
#
#                                           nama_pekerjaan  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# ...

# %%
dfs.fillna(value='Data tidak tersedia', inplace=True)
dfs
# Out:
#        id_pekerjaan id_perusahaan  \
# 0        3757940104      553718.0
# 1        3757940025     2192142.0
# 2        3757938019      474443.0
# 3        3757938018    18213359.0
# 4        3757937095      437225.0
# ...             ...           ...
# 33241     133114754    77766802.0
# 33242     108965123           0.0
# 33243     102339515    52132271.0
# 33244      85008768           0.0
# 33245       3958427      630152.0
#
#                                           nama_pekerjaan  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# ...

# %% [markdown]
# > Adapun untuk mengatasi missing value yang terdapat pada kolom lainnya, atas pertimbangan dan kesepakatan Tim Sevengers bersama, untuk mengisi missing value tersebut dengan keterangan "Data Tidak Tersedia" dan mengisi nilai "0" untuk tipe data yang numeric.

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_pekerjaan                  33246 non-null  int64
#  1   id_perusahaan                 33246 non-null  object
#  2   nama_pekerjaan                33246 non-null  object
#  3   deskripsi_pekerjaan           33246 non-null  object
#  4   jenis_pekerjaan_terformat     33246 non-null  object
#  5   lokasi_pekerjaan              33246 non-null  object
#  6   diperbolehkan_jarak_jauh      33246 non-null  object
#  7   tingkat_pengalaman_terformat  33246 non-null  object
#  8   deskripsi_keterampilan        33246 non-null  object
#  9   jenis_pekerjaan               33246 non-null  object
#  10  gaji_maksimal                 33246 non-null  float64
#  11  gaji_median                   33246 non-null  float64
# ...

# %%
dfs.isna().sum()
# Out:
# id_pekerjaan                    0
# id_perusahaan                   0
# nama_pekerjaan                  0
# deskripsi_pekerjaan             0
# jenis_pekerjaan_terformat       0
# lokasi_pekerjaan                0
# diperbolehkan_jarak_jauh        0
# tingkat_pengalaman_terformat    0
# deskripsi_keterampilan          0
# jenis_pekerjaan                 0
# gaji_maksimal                   0
# gaji_median                     0
# gaji_minimal                    0
# periode_pembayaran              0
# mata_uang                       0
# jenis_kompensasi                0
# kode_kemampuan                  0
# jenis                           0
# nama_perusahaan                 0
# deskripsi_perusahaan            0
# ukuran_perusahaan               0
# negara_bagian_perusahaan        0
# negara_perusahaan               0
# kota_perusahaan                 0
# gaji_bulanan_minimal            0
# dtype: int64

# %% [markdown]
# #### **Duplicate Value**

# %%
dfs.duplicated().sum()
# Out:
# 0

# %%
# Memeriksa banyak nilai duplikat di seluruh DataFrame.

jumlah_duplikat_total = dfs.duplicated().sum()
print("Jumlah nilai duplikat di dataframe DFS :", jumlah_duplikat_total)
# Out:
# Jumlah nilai duplikat di dataframe DFS : 0

# %%
# Mengidentifikasi baris-baris yang unik (tidak duplikat).
duplikat_benar = dfs.duplicated(keep=False)

# Menampilkan baris-baris yang tidak duplikat.
display(dfs[~duplikat_benar])
# Out:
#        id_pekerjaan id_perusahaan  \
# 0        3757940104      553718.0
# 1        3757940025     2192142.0
# 2        3757938019      474443.0
# 3        3757938018    18213359.0
# 4        3757937095      437225.0
# ...             ...           ...
# 33241     133114754    77766802.0
# 33242     108965123           0.0
# 33243     102339515    52132271.0
# 33244      85008768           0.0
# 33245       3958427      630152.0
#
#                                           nama_pekerjaan  \
# 0                                  Hearing Care Provider
# 1      Shipping & Receiving Associate 2nd shift (Beav...
# 2                                   Manager, Engineering
# 3                                                   Cook
# 4            Principal Cloud Security Architect (Remote)
# ...                                                  ...
# 33241                                      Sales Manager
# 33242                    Office Administrative Assistant
# ...

# %% [markdown]
# > Pada dataframe dfs tidak ditemukan adanya duplicate value.

# %% [markdown]
# #### **Outliers**

# %% [markdown]
# > Berikut penanganan Outliers menggunakan Trimming.

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_pekerjaan                  33246 non-null  int64
#  1   id_perusahaan                 33246 non-null  object
#  2   nama_pekerjaan                33246 non-null  object
#  3   deskripsi_pekerjaan           33246 non-null  object
#  4   jenis_pekerjaan_terformat     33246 non-null  object
#  5   lokasi_pekerjaan              33246 non-null  object
#  6   diperbolehkan_jarak_jauh      33246 non-null  object
#  7   tingkat_pengalaman_terformat  33246 non-null  object
#  8   deskripsi_keterampilan        33246 non-null  object
#  9   jenis_pekerjaan               33246 non-null  object
#  10  gaji_maksimal                 33246 non-null  float64
#  11  gaji_median                   33246 non-null  float64
# ...

# %%
# Function to create histogram and boxplot.
# This functions takes a dataframe (df) and the variable of interest as arguments.

def diagnostic_plots(dfs, variable):
    # Define figure size
    plt.figure(figsize=(25, 4))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(dfs[variable], bins=30)
    plt.title('Histogram')

    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(y=dfs[variable])
    plt.title('Boxplot')

    plt.show()

# %%
import numpy as np

# Filter numeric columns
numeric_columns = dfs.select_dtypes(include=[np.number]).columns

# Calculate IQR for each numeric column
Q1 = dfs[numeric_columns].quantile(0.25)
Q3 = dfs[numeric_columns].quantile(0.75)
IQR = Q3 - Q1

# Determine upper and lower bounds for each numeric column
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

# Identify outliers
outliers = ((dfs[numeric_columns] < lower_bound) | (dfs[numeric_columns] > upper_bound)).any(axis=1)

# Display the number of outliers
print("Number of outliers:", outliers.sum())

# Display the rows containing outliers
if outliers.any():
    print("\nRows containing outliers:")
# Out:
# Number of outliers: 10097
#
# Rows containing outliers:

# %%
# Menghitung IQR untuk setiap kolom numerik
Q1 = dfs[numeric_columns].quantile(0.25)
Q3 = dfs[numeric_columns].quantile(0.75)
IQR = Q3 - Q1

# Tentukan batas atas dan batas bawah untuk setiap kolom numerik
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

# Identifikasi outlier
outliers = ((dfs[numeric_columns] < lower_bound) | (dfs[numeric_columns] > upper_bound)).any(axis=1)

# Menampilkan jumlah outlier
print("Jumlah outlier:", outliers.sum())

# Menampilkan baris yang mengandung outlier
if outliers.any():
    print("\nBaris yang mengandung outlier:")
    print(dfs[outliers])
else:
    print("\nTidak ada outlier dalam data.")
# Out:
# Jumlah outlier: 10097
#
# Baris yang mengandung outlier:
#        id_pekerjaan id_perusahaan  \
# 0        3757940104      553718.0
# 3        3757938018    18213359.0
# 4        3757937095      437225.0
# 8        3757936097    18213359.0
# 11       3757935381    19181907.0
# ...             ...           ...
# 33241     133114754    77766802.0
# 33242     108965123           0.0
# 33243     102339515    52132271.0
# 33244      85008768           0.0
# 33245       3958427      630152.0
#
#                                     nama_pekerjaan  \
# 0                            Hearing Care Provider
# 3                                             Cook
# 4      Principal Cloud Security Architect (Remote)
# 8                                       Dishwasher
# 11                Insights Analyst - Auto Industry
# ...                                            ...
# 33241                                Sales Manager
# 33242              Office Administrative Assistant
# ...

# %%
# Let's start with the variable from the dff dataset.

diagnostic_plots(dfs, 'gaji_maksimal')
print('\nSkewness Value : ', dfs['gaji_maksimal'].skew())
# Out:
# Skewness Value :  182.27875913055715

# %%
# Let's start with the variable from the dff dataset.

diagnostic_plots(dfs, 'gaji_median')
print('\nSkewness Value : ', dfs['gaji_median'].skew())
# Out:
# Skewness Value :  19.122683493093525

# %%
# Let's start with the variable from the dff dataset.

diagnostic_plots(dfs, 'gaji_minimal')
print('\nSkewness Value : ', dfs['gaji_minimal'].skew())
# Out:
# Skewness Value :  2.6574925182913933

# %%
# Let's start with the variable from the dff dataset.

diagnostic_plots(dfs, 'gaji_bulanan_minimal')
print('\nSkewness Value : ', dfs['gaji_bulanan_minimal'].skew())
# Out:
# Skewness Value :  134.09205502209474

# %%
# Let's find outliers in DFf.

diagnostic_plots(dfs, 'gaji_maksimal')
diagnostic_plots(dfs, 'gaji_median')
diagnostic_plots(dfs, 'gaji_minimal')
diagnostic_plots(dfs, 'gaji_bulanan_minimal')

# %%
# Function to find upper and lower boundaries for skewed distributed variables
# Let's calculate the boundaries outside which sit the outliers for skewed distributions
# Distance passed as an argument, gives us the option to estimate 1.5 times or 3 times the IQR to calculate the boundaries.

def find_skewed_boundaries(dfs, variable, distance):
    IQR = dfs[variable].quantile(0.75) - dfs[variable].quantile(0.25)

    lower_boundary = dfs[variable].quantile(0.25) - (IQR * distance)
    upper_boundary = dfs[variable].quantile(0.75) + (IQR * distance)

    return upper_boundary, lower_boundary

# %%
# Limits for `gaji_maksimal`
gaji_maksimal_upper_limit, gaji_maksimal_lower_limit = find_skewed_boundaries(dfs, 'gaji_maksimal', 1.5)
print('gaji_maksimal_upper_limit : ', gaji_maksimal_upper_limit)
print('gaji_maksimal_lower_limit : ', gaji_maksimal_lower_limit, '\n')

# Limits for `gaji_median`
gaji_median_upper_limit, gaji_median_lower_limit = find_skewed_boundaries(dfs, 'gaji_median', 1.5)
print('gaji_median_upper_limit : ', gaji_median_upper_limit)
print('gaji_median_lower_limit : ', gaji_median_lower_limit, '\n')

# Limits for `gaji_minimal`
gaji_minimal_upper_limit, gaji_minimal_lower_limit = find_skewed_boundaries(dfs, 'gaji_minimal', 1.5)
print('gaji_minimal_upper_limit : ', gaji_minimal_upper_limit)
print('gaji_minimal_lower_limit : ', gaji_minimal_lower_limit, '\n')

# Limits for `gaji_bulanan_minimal`
gaji_bulanan_minimal_upper_limit, gaji_bulanan_minimal_lower_limit = find_skewed_boundaries(dfs, 'gaji_bulanan_minimal', 1.5)
print('gaji_bulanan_minimal_upper_limit : ', gaji_bulanan_minimal_upper_limit)
print('gaji_bulanan_minimal_lower_limit : ', gaji_bulanan_minimal_lower_limit, '\n')
# Out:
# gaji_maksimal_upper_limit :  130.0
# gaji_maksimal_lower_limit :  -78.0
#
# gaji_median_upper_limit :  0.0
# gaji_median_lower_limit :  0.0
#
# gaji_minimal_upper_limit :  105.0
# gaji_minimal_lower_limit :  -63.0
#
# gaji_bulanan_minimal_upper_limit :  10323.0
# gaji_bulanan_minimal_lower_limit :  -6193.799999999999

# %%
# Flag the outliers in category `gaji_maksimal`
outliers_gaji_maksimal = np.where(dfs['gaji_maksimal'] > gaji_maksimal_upper_limit, True,
                       np.where(dfs['gaji_maksimal'] < gaji_maksimal_lower_limit, True, False))

# Flag the outliers in category `gaji_median`
outliers_gaji_median = np.where(dfs['gaji_median'] > gaji_median_upper_limit, True,
                       np.where(dfs['gaji_median'] < gaji_median_lower_limit, True, False))

# Flag the outliers in category `gaji_minimal`
outliers_gaji_minimal = np.where(dfs['gaji_minimal'] > gaji_minimal_upper_limit, True,
                       np.where(dfs['gaji_minimal'] < gaji_minimal_lower_limit, True, False))

# Flag the outliers in category `gaji_bulanan_minimal`
outliers_gaji_bulanan_minimal = np.where(dfs['gaji_bulanan_minimal'] > gaji_bulanan_minimal_upper_limit, True,
                       np.where(dfs['gaji_bulanan_minimal'] < gaji_bulanan_minimal_lower_limit, True, False))

print(outliers_gaji_maksimal[:10])
# Out:
# [False False False False  True False False False False False]

# %%
# Let's trimm the dataset

dfs_trimmed = dfs.loc[~(outliers_gaji_maksimal + outliers_gaji_median + outliers_gaji_minimal +
                            outliers_gaji_bulanan_minimal)]

print('Size dataset - Before trimming : ', dfs.shape)
print('Size dataset - After trimming  : ', dfs_trimmed.shape)
# Out:
# Size dataset - Before trimming :  (33246, 25)
# Size dataset - After trimming  :  (23225, 25)

# %%
print('\ngaji_maksimal - Before Trimming')
diagnostic_plots(dfs, 'gaji_maksimal')
print('\ngaji_maksimal - After Trimming')
diagnostic_plots(dfs_trimmed, 'gaji_maksimal')

print('\ngaji_median - Before Trimming')
diagnostic_plots(dfs, 'gaji_median')
print('\ngaji_median - After Trimming')
diagnostic_plots(dfs_trimmed, 'gaji_median')

print('\ngaji_minimal - Before Trimming')
diagnostic_plots(dfs, 'gaji_minimal')
print('\ngaji_minimal - After Trimming')
diagnostic_plots(dfs_trimmed, 'gaji_minimal')

print('\ngaji_bulanan_minimal - Before Trimming')
diagnostic_plots(dfs, 'gaji_bulanan_minimal')
print('\ngaji_bulanan_minimal - After Trimming')
diagnostic_plots(dfs_trimmed, 'gaji_bulanan_minimal')
# Out:
# gaji_maksimal - Before Trimming
# gaji_maksimal - After Trimming
# gaji_median - Before Trimming
# gaji_median - After Trimming
# gaji_minimal - Before Trimming
# gaji_minimal - After Trimming
# gaji_bulanan_minimal - Before Trimming
# gaji_bulanan_minimal - After Trimming

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_pekerjaan                  33246 non-null  int64
#  1   id_perusahaan                 33246 non-null  object
#  2   nama_pekerjaan                33246 non-null  object
#  3   deskripsi_pekerjaan           33246 non-null  object
#  4   jenis_pekerjaan_terformat     33246 non-null  object
#  5   lokasi_pekerjaan              33246 non-null  object
#  6   diperbolehkan_jarak_jauh      33246 non-null  object
#  7   tingkat_pengalaman_terformat  33246 non-null  object
#  8   deskripsi_keterampilan        33246 non-null  object
#  9   jenis_pekerjaan               33246 non-null  object
#  10  gaji_maksimal                 33246 non-null  float64
#  11  gaji_median                   33246 non-null  float64
# ...

# %% [markdown]
# #### **Statistik deskriptif**

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_pekerjaan                  33246 non-null  int64
#  1   id_perusahaan                 33246 non-null  object
#  2   nama_pekerjaan                33246 non-null  object
#  3   deskripsi_pekerjaan           33246 non-null  object
#  4   jenis_pekerjaan_terformat     33246 non-null  object
#  5   lokasi_pekerjaan              33246 non-null  object
#  6   diperbolehkan_jarak_jauh      33246 non-null  object
#  7   tingkat_pengalaman_terformat  33246 non-null  object
#  8   deskripsi_keterampilan        33246 non-null  object
#  9   jenis_pekerjaan               33246 non-null  object
#  10  gaji_maksimal                 33246 non-null  float64
#  11  gaji_median                   33246 non-null  float64
# ...

# %%
# Menghitung statistik deskriptif.
deskripsi_statistik = dfs.describe()

# Menampilkan statistik deskriptif.
deskripsi_statistik
# Out:
#        id_pekerjaan  gaji_maksimal    gaji_median   gaji_minimal  \
# count  3.324600e+04   3.324600e+04   33246.000000   33246.000000
# mean   3.723675e+09   2.436083e+05    2185.738083   20938.024932
# std    9.264310e+07   3.839519e+07   21543.911210   45013.069012
# min    3.958427e+06   0.000000e+00       0.000000       0.000000
# 25%    3.697367e+09   0.000000e+00       0.000000       0.000000
# 50%    3.749345e+09   0.000000e+00       0.000000       0.000000
# 75%    3.756905e+09   5.200000e+01       0.000000      42.000000
# max    3.757940e+09   7.000090e+09  998426.000000  800000.000000
#
#        gaji_bulanan_minimal
# count          3.324600e+04
# mean           3.610683e+03
# std            1.528728e+05
# min            0.000000e+00
# 25%            0.000000e+00
# 50%            0.000000e+00
# 75%            4.129200e+03
# max            2.400000e+07

# %% [markdown]
# ### **Exploratory Data Analysis (EDA)**

# %%
dfs.describe().T
# Out:
#                         count          mean           std        min  \
# id_pekerjaan          33246.0  3.723675e+09  9.264310e+07  3958427.0
# gaji_maksimal         33246.0  2.436083e+05  3.839519e+07        0.0
# gaji_median           33246.0  2.185738e+03  2.154391e+04        0.0
# gaji_minimal          33246.0  2.093802e+04  4.501307e+04        0.0
# gaji_bulanan_minimal  33246.0  3.610683e+03  1.528728e+05        0.0
#
#                                25%           50%           75%           max
# id_pekerjaan          3.697367e+09  3.749345e+09  3.756905e+09  3.757940e+09
# gaji_maksimal         0.000000e+00  0.000000e+00  5.200000e+01  7.000090e+09
# gaji_median           0.000000e+00  0.000000e+00  0.000000e+00  9.984260e+05
# gaji_minimal          0.000000e+00  0.000000e+00  4.200000e+01  8.000000e+05
# gaji_bulanan_minimal  0.000000e+00  0.000000e+00  4.129200e+03  2.400000e+07

# %% [markdown]
# #### **Visualisasi Distribusi Gaji**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Memuat DataFrame dari file CSV
dataframe = pd.read_csv('/content/drive/MyDrive/Tim 5A Final Project Drive/lowongan_kerja.csv')

# Visualisasi distribusi gaji
plt.figure(figsize=(10, 6))
sns.histplot(dataframe['gaji_minimal'], kde=True, color='blue', label='Gaji Minimal')
sns.histplot(dataframe['gaji_maksimal'], kde=True, color='red', label='Gaji Maksimal')
sns.histplot(dataframe['gaji_tengah'], kde=True, color='green', label='Gaji Tengah')
plt.title('Distribusi Gaji')
plt.xlabel('Gaji')
plt.legend()
plt.show()

# %% [markdown]
# > Grafik distribusi gaji di atas menunjukkan bahwa distribusi gaji yang ada tidak merata, yang kemudian ditandai dengan banyak karyawan yang memiliki gaji rendah dan hanya sedikit karyawan yang memiliki gaji tinggi. Dengan **gaji tengah** adalah Rp3.500.000, **gaji minimum** adalah Rp500.000, dan **gaji maksimum** adalah Rp1.000.000.000. Mayoritas karyawan memiliki gaji antara Rp1.000.000 dan Rp5.000.000.

# %% [markdown]
# #### **Hubungan antara Gaji Minimal dan Gaji Maksimal**

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x='gaji_minimal', y='gaji_maksimal', data=dataframe)
plt.title('Hubungan antara Gaji Minimal dan Gaji Maksimal')
plt.show()

# %% [markdown]
# > Scatterplot di atas menunjukkan bahwa adanya korelasi positif antara gaji_minimal (upah minimum) dan gaji_maksimal (upah maksimum). Ini berarti bahwa ketika upah minimum meningkat, upah maksimum juga cenderung meningkat.

# %% [markdown]
# ### **Feature Engineering**

# %% [markdown]
# Berikut terdapat beberapa fitur baru yang didapatkan, adalah sebagai berikut:

# %% [markdown]
# #### **Distribusi Pekerjaan Berdasarkan Jenisnya**

# %%
# Distribusi pekerjaan berdasarkan jenisnya
distribusi_jenis_pekerjaan = dfs['jenis_pekerjaan_terformat'].value_counts()

# Plot
plt.figure(figsize=(12, 7))
distribusi_jenis_pekerjaan.plot(kind='bar', color='skyblue')
plt.title('Distribusi Pekerjaan berdasarkan Jenisnya')
plt.xlabel('Jenis Pekerjaan')
plt.ylabel('Jumlah Pekerjaan')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# > Berdasarkan grafik di atas, jenis pekerjaan *full-time* mendominasi lowongan pekerjaan. Sedangkan jenis pekerjaan *contract* dan *part-time* masih jarang dibandingkan dengan full-time . Dan untuk jenis pekerjaan *temporary*, *internship*, dan jenis posisi lainnya bahkan lebih jarang di lowongan pekerjaan.

# %% [markdown]
# #### **Top 10 Companies with The Most Job Vacancies**

# %%
# Mengecualikan nilai "Data tidak tersedia"
filtered_df = dfs[dfs['nama_perusahaan'] != 'Data tidak tersedia']

# Mendapatkan top 10 perusahaan dengan jumlah lowongan pekerjaan terbanyak
top_10_perusahaan = filtered_df['nama_perusahaan'].value_counts().head(10)

# Plot
plt.figure(figsize=(12, 7))
top_10_perusahaan.plot(kind='bar', color='lightblue')
plt.title('Top 10 Perusahaan dengan Lowongan Pekerjaan Terbanyak')
plt.xlabel('Nama Perusahaan')
plt.ylabel('Jumlah Lowongan Pekerjaan')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# > Insight Global merupakan salah satu perusahaan dengan lowongan kerja terbanyak.

# %% [markdown]
# #### **Top 10 Kemampuan Yang Dibutuhkan**

# %%
# Splitting skills by comma and creating a list of skills
list_kemampuan = dfs['kode_kemampuan'].str.split(',').explode()

# Counting the occurrences of each skill
kemampuan_count = list_kemampuan.str.strip().value_counts()

# Plotting the top 10 most common skills
top_skills = kemampuan_count.head(10)
plt.figure(figsize=(10, 6))
top_skills.sort_values().plot(kind='barh')
plt.title('Top 10 kemampuan yang dibutuhkan')
plt.xlabel('Frequency')
plt.ylabel('Skills')
plt.show()

# %% [markdown]
# > IT atau Information Technology merupakan skill yang paling dibutuhkan dan dicari oleh perusahaan.

# %% [markdown]
# #### **Tingkat Pengalaman Terformat**

# %% [markdown]
# > Untuk melihat apakah gaji berhubungan dengan tingkat pengalaman pada perusahaan.

# %%
import matplotlib.pyplot as plt

# Assuming you have already imported necessary libraries and defined DataFrame

list_pengalaman = dfs['tingkat_pengalaman_terformat'].str.split(',').explode()

# Counting the occurrences of each skill
pengalaman_count = list_pengalaman.str.strip().value_counts()

pengalaman = pengalaman_count.head()
plt.figure(figsize=(10, 6))
pengalaman.plot(kind='pie', autopct='%1.1f%%')
plt.title('Tingkat Kemampuan')
plt.show()

# %% [markdown]
# > Dapat kita lihat bahwa tingkat kemmapuan mid senior level paling besar yaitu 34,6% sehingga dapat disimpulkan bahwa rata-rata karyawan pada perusahaan memiliki tingkat kemampuan yaitu mid senior level atau sudah berpengalaman.

# %% [markdown]
# #### **Ukuran Perusahaan**

# %% [markdown]
# > Untuk melihat rata-rata ukuran perusahaan.

# %%
import matplotlib.pyplot as plt

# Convert the column to float data type
dfs['ukuran_perusahaan'] = dfs['ukuran_perusahaan'].astype(float)

# Counting the occurrences of each value
ukuran_perusahaan_count = dfs['ukuran_perusahaan'].value_counts()

# Plotting the top 10 most common values
perusahaan = ukuran_perusahaan_count.head()
plt.figure(figsize=(10, 6))
perusahaan.plot(kind='pie', autopct='%1.1f%%')
plt.title('Ukuran Perusahaan')
plt.show()

# %% [markdown]
# > Ukuran perusahaan paling banyak yaitu pada 7.0 sebanyak 37,4 persen.

# %% [markdown]
# #### **Top 10 Spesialisasi Perusahaan**

# %%
# Splitting skills by comma and creating a list of skills
spesialisasi_perusahaan = df_spesialisasi_perusahaan['spesialisasi'].str.split(',').explode()

# Counting the occurrences of each skill
spesialisasi_perusahaan = spesialisasi_perusahaan.str.strip().value_counts()

# Selecting the top 10 most common skills
spesialisasi_top10 = spesialisasi_perusahaan.head(10)

# Plotting the top 10 most common skills
plt.figure(figsize=(10, 6))
ax = spesialisasi_top10.plot(kind='barh')

# Annotating each bar with its count and percentage value
for i, (count, percentage) in enumerate(zip(spesialisasi_top10, spesialisasi_top10 / len(df_spesialisasi_perusahaan) * 100)):
    ax.text(count + 0.2, i, f'{count} ({percentage:.1f}%)', va='center')

plt.title('Spesialisasi Perusahaan')
plt.xlabel('Frequency')
plt.ylabel('Spesialisasi Perusahaan')
plt.show()

# %% [markdown]
# > Dapat dilihat dari TOP 10 spesialisasi perusahaan yang memiliki jumlah paling banyak, yaitu engineering. Hal ini sangat berguna untuk para pelamar sebagai bahan referensi dalam mengidentifikasi tren industri, menyesuaikan kualifikasi dan keterampilan mereka, serta menentukan strategi pencarian pekerjaan yang lebih efektif. Dengan memahami permintaan pasar tenaga kerja dalam spesialisasi tertentu, para pelamar dapat mengarahkan upaya mereka untuk meningkatkan daya saing dan kesempatan sukses dalam mendapatkan pekerjaan yang sesuai dengan minat dan keahlian mereka.

# %% [markdown]
# #### **Top 10 Industry with The Most Job Vacancies**

# %%
# Get the top 10 companies with the most job vacancies
top_10_industri = df_industri_perusahaan['industri'].value_counts().head(10)

# Plot
plt.figure(figsize=(12, 7))
top_10_industri.plot(kind='pie', autopct='%1.1f%%')
plt.title('Top 10 Industri dengan Lowongan Pekerjaan Terbanyak')
plt.xlabel('Nama Industri')
plt.ylabel('Jumlah Lowongan Pekerjaan')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# > Berdasarkan pie chart di atas, dapat dilihat bahwa industri Staffing and Recruiting memiliki lowongan pekerjaan terbanyak yakni 28,9 persen. Diikuti dengan Information Technology & Services sebanyak 13,0 persen, serta IT Services and IT Consulting sebanyak 12,9 persen.
